# %%
import random
import numpy as np
from deap import base, creator, tools, algorithms
import time

# %%
import math
# Rastrigin function
def rastrigin(individual):
    n = len(individual)
    A = 10
    return A * n + sum(x**2 - A * math.cos(2 * math.pi * x) for x in individual),

# Ackley function
def ackley(individual):
    n = len(individual)
    sum1 = sum(x**2 for x in individual)
    sum2 = sum(math.cos(2 * math.pi * x) for x in individual)
    return -20 * math.exp(-0.2 * math.sqrt(sum1 / n)) - math.exp(sum2 / n) + 20 + math.e,

# Rosenbrock function
def rosenbrock(individual):
    n = len(individual)
    return sum(100 * (individual[i+1] - individual[i]**2)**2 + (individual[i] - 1)**2 for i in range(n - 1)),

# %%
# Main function to run the Genetic Algorithm
def main(popul=300, generations=400, parent=0.5, mutate=0.2):
    pop = toolbox.population(n=popul)
    hof = tools.HallOfFame(1)
    stats = tools.Statistics(lambda ind: ind.fitness.values)
    # stats.register("avg", np.mean)
    # stats.register("std", np.std)
    # stats.register("min", np.min)
    # stats.register("max", np.max)

    algorithms.eaSimple(pop, toolbox, cxpb=parent, mutpb=mutate, ngen=generations, stats=stats, halloffame=hof, verbose=False)

    return pop, stats, hof

# %% [markdown]
# # Rastrigin

# %%
random.seed(12345)
# define parameters
n_dim = 5
pmin_ = -5.12
pmax_ = 5.12
alpha = 0.8
par = 0.8
mut = 0.05

eval_fun = rastrigin

# ------------------------------------------- RUN IT -------------------------------------

# Create the Fitness and Individual classes
creator.create("FitnessMin", base.Fitness, weights=(-1.0,))
creator.create("Individual", list, fitness=creator.FitnessMin)

# Register toolbox functions
toolbox = base.Toolbox()
toolbox.register("attr_float", random.uniform, pmin_, pmax_)
toolbox.register("individual", tools.initRepeat, creator.Individual, toolbox.attr_float, n=n_dim)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)

toolbox.register("mate", tools.cxBlend, alpha=alpha)
toolbox.register("mutate", tools.mutGaussian, mu=0, sigma=1, indpb=mut)
toolbox.register("select", tools.selTournament, tournsize=3)
toolbox.register("evaluate", eval_fun)

fill = []
fill_t = []
for i in range(10):
    if __name__ == "__main__":
        start_time = time.time() #time
        pop, stats, hof = main(popul=300,generations=400, parent=par, mutate=mut)
        end_time = time.time() #time
        elapsed_time = end_time - start_time
        # print("Best individual is: ",  hof[0])
        # print("Best fitness value is: ", hof[0].fitness.values[0])
        # print("Time to execute: ", elapsed_time)
        fill.append(hof[0].fitness.values[0])
        fill_t.append(elapsed_time)

print("Best fitness value is: ", min(fill))
print("Best AVG fitness value is: ", np.mean(fill))
print('-------------------------------------')
print("Best AVG time is: ", np.mean(fill_t))
# Out:
# Best fitness value is:  0.0
# Best AVG fitness value is:  0.2097920652420342
# -------------------------------------
# Best AVG time is:  1.7499835729598998

# %%
random.seed(12345)
# define parameters
n_dim = 10
pmin_ = -5.12
pmax_ = 5.12
alpha = 0.8
par = 0.8
mut = 0.05

eval_fun = rastrigin

# ------------------------------------------- RUN IT -------------------------------------

# Create the Fitness and Individual classes
creator.create("FitnessMin", base.Fitness, weights=(-1.0,))
creator.create("Individual", list, fitness=creator.FitnessMin)

# Register toolbox functions
toolbox = base.Toolbox()
toolbox.register("attr_float", random.uniform, pmin_, pmax_)
toolbox.register("individual", tools.initRepeat, creator.Individual, toolbox.attr_float, n=n_dim)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)

toolbox.register("mate", tools.cxBlend, alpha=alpha)
toolbox.register("mutate", tools.mutGaussian, mu=0, sigma=1, indpb=mut)
toolbox.register("select", tools.selTournament, tournsize=3)
toolbox.register("evaluate", eval_fun)

fill = []
fill_t = []
for i in range(10):
    if __name__ == "__main__":
        start_time = time.time() #time
        pop, stats, hof = main(popul=300,generations=400, parent=par, mutate=mut)
        end_time = time.time() #time
        elapsed_time = end_time - start_time
        # print("Best individual is: ",  hof[0])
        # print("Best fitness value is: ", hof[0].fitness.values[0])
        # print("Time to execute: ", elapsed_time)
        fill.append(hof[0].fitness.values[0])
        fill_t.append(elapsed_time)

print("Best fitness value is: ", min(fill))
print("Best AVG fitness value is: ", np.mean(fill))
print('-------------------------------------')
print("Best AVG time is: ", np.mean(fill_t))
# Out:
# c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\deap\creator.py:138: RuntimeWarning: A class named 'FitnessMin' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "
# c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\deap\creator.py:138: RuntimeWarning: A class named 'Individual' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "
# Best fitness value is:  0.9949590570933822
# Best AVG fitness value is:  15.777403684456763
# -------------------------------------
# Best AVG time is:  2.1452856063842773

# %%
random.seed(12345)
# define parameters
n_dim = 20
pmin_ = -5.12
pmax_ = 5.12
alpha = 0.8
par = 0.8
mut = 0.05

eval_fun = rastrigin

# ------------------------------------------- RUN IT -------------------------------------

# Create the Fitness and Individual classes
creator.create("FitnessMin", base.Fitness, weights=(-1.0,))
creator.create("Individual", list, fitness=creator.FitnessMin)

# Register toolbox functions
toolbox = base.Toolbox()
toolbox.register("attr_float", random.uniform, pmin_, pmax_)
toolbox.register("individual", tools.initRepeat, creator.Individual, toolbox.attr_float, n=n_dim)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)

toolbox.register("mate", tools.cxBlend, alpha=alpha)
toolbox.register("mutate", tools.mutGaussian, mu=0, sigma=1, indpb=mut)
toolbox.register("select", tools.selTournament, tournsize=3)
toolbox.register("evaluate", eval_fun)

fill = []
fill_t = []
for i in range(10):
    if __name__ == "__main__":
        start_time = time.time() #time
        pop, stats, hof = main(popul=300,generations=400, parent=par, mutate=mut)
        end_time = time.time() #time
        elapsed_time = end_time - start_time
        # print("Best individual is: ",  hof[0])
        # print("Best fitness value is: ", hof[0].fitness.values[0])
        # print("Time to execute: ", elapsed_time)
        fill.append(hof[0].fitness.values[0])
        fill_t.append(elapsed_time)

print("Best fitness value is: ", min(fill))
print("Best AVG fitness value is: ", np.mean(fill))
print('-------------------------------------')
print("Best AVG time is: ", np.mean(fill_t))
# Out:
# Best fitness value is:  119.95466677183144
# Best AVG fitness value is:  132.91226854479103
# -------------------------------------
# Best AVG time is:  2.96988365650177

# %% [markdown]
# # Ackley

# %%
random.seed(12345)
# define parameters
n_dim = 5
pmin_ = -32.769
pmax_ = 32.769
alpha = 0.8
par = 0.95
mut = 0.01

eval_fun = ackley

# ------------------------------------------- RUN IT -------------------------------------

# Create the Fitness and Individual classes
creator.create("FitnessMin", base.Fitness, weights=(-1.0,))
creator.create("Individual", list, fitness=creator.FitnessMin)

# Register toolbox functions
toolbox = base.Toolbox()
toolbox.register("attr_float", random.uniform, pmin_, pmax_)
toolbox.register("individual", tools.initRepeat, creator.Individual, toolbox.attr_float, n=n_dim)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)

toolbox.register("mate", tools.cxBlend, alpha=alpha)
toolbox.register("mutate", tools.mutGaussian, mu=0, sigma=1, indpb=mut)
toolbox.register("select", tools.selTournament, tournsize=3)
toolbox.register("evaluate", eval_fun)

fill = []
fill_t = []
for i in range(10):
    if __name__ == "__main__":
        start_time = time.time() #time
        pop, stats, hof = main(popul=300,generations=400, parent=par, mutate=mut)
        end_time = time.time() #time
        elapsed_time = end_time - start_time
        # print("Best individual is: ",  hof[0])
        # print("Best fitness value is: ", hof[0].fitness.values[0])
        # print("Time to execute: ", elapsed_time)
        fill.append(hof[0].fitness.values[0])
        fill_t.append(elapsed_time)

print("Best fitness value is: ", min(fill))
print("Best AVG fitness value is: ", np.mean(fill))
print('-------------------------------------')
print("Best AVG time is: ", np.mean(fill_t))
# Out:
# Best fitness value is:  4.440892098500626e-16
# Best AVG fitness value is:  4.440892098500626e-16
# -------------------------------------
# Best AVG time is:  1.878270149230957

# %%
random.seed(12345)
# define parameters
n_dim = 10
pmin_ = -32.769
pmax_ = 32.769
alpha = 0.8
par = 0.95
mut = 0.05

eval_fun = ackley

# ------------------------------------------- RUN IT -------------------------------------

# Create the Fitness and Individual classes
creator.create("FitnessMin", base.Fitness, weights=(-1.0,))
creator.create("Individual", list, fitness=creator.FitnessMin)

# Register toolbox functions
toolbox = base.Toolbox()
toolbox.register("attr_float", random.uniform, pmin_, pmax_)
toolbox.register("individual", tools.initRepeat, creator.Individual, toolbox.attr_float, n=n_dim)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)

toolbox.register("mate", tools.cxBlend, alpha=alpha)
toolbox.register("mutate", tools.mutGaussian, mu=0, sigma=1, indpb=mut)
toolbox.register("select", tools.selTournament, tournsize=3)
toolbox.register("evaluate", eval_fun)

fill = []
fill_t = []
for i in range(10):
    if __name__ == "__main__":
        start_time = time.time() #time
        pop, stats, hof = main(popul=300,generations=400, parent=par, mutate=mut)
        end_time = time.time() #time
        elapsed_time = end_time - start_time
        # print("Best individual is: ",  hof[0])
        # print("Best fitness value is: ", hof[0].fitness.values[0])
        # print("Time to execute: ", elapsed_time)
        fill.append(hof[0].fitness.values[0])
        fill_t.append(elapsed_time)

print("Best fitness value is: ", min(fill))
print("Best AVG fitness value is: ", np.mean(fill))
print('-------------------------------------')
print("Best AVG time is: ", np.mean(fill_t))
# Out:
# Best fitness value is:  1.117570080921837e-08
# Best AVG fitness value is:  4.08991486899879e-08
# -------------------------------------
# Best AVG time is:  2.381809878349304

# %%
random.seed(12345)
# define parameters
n_dim = 20
pmin_ = -32.769
pmax_ = 32.769
alpha = 0.8
par = 0.95
mut = 0.05

eval_fun = ackley

# ------------------------------------------- RUN IT -------------------------------------

# Create the Fitness and Individual classes
creator.create("FitnessMin", base.Fitness, weights=(-1.0,))
creator.create("Individual", list, fitness=creator.FitnessMin)

# Register toolbox functions
toolbox = base.Toolbox()
toolbox.register("attr_float", random.uniform, pmin_, pmax_)
toolbox.register("individual", tools.initRepeat, creator.Individual, toolbox.attr_float, n=n_dim)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)

toolbox.register("mate", tools.cxBlend, alpha=alpha)
toolbox.register("mutate", tools.mutGaussian, mu=0, sigma=1, indpb=mut)
toolbox.register("select", tools.selTournament, tournsize=3)
toolbox.register("evaluate", eval_fun)

fill = []
fill_t = []
for i in range(10):
    if __name__ == "__main__":
        start_time = time.time() #time
        pop, stats, hof = main(popul=300,generations=400, parent=par, mutate=mut)
        end_time = time.time() #time
        elapsed_time = end_time - start_time
        # print("Best individual is: ",  hof[0])
        # print("Best fitness value is: ", hof[0].fitness.values[0])
        # print("Time to execute: ", elapsed_time)
        fill.append(hof[0].fitness.values[0])
        fill_t.append(elapsed_time)

print("Best fitness value is: ", min(fill))
print("Best AVG fitness value is: ", np.mean(fill))
print('-------------------------------------')
print("Best AVG time is: ", np.mean(fill_t))
# Out:
# Best fitness value is:  19.54124763981014
# Best AVG fitness value is:  19.934562021743456
# -------------------------------------
# Best AVG time is:  3.3693495273590086

# %% [markdown]
# # Rosenbrock

# %%
random.seed(12345)
# define parameters
n_dim = 5
pmin_ = -5
pmax_ = 10
alpha = 0.8
par = 0.7
mut = 0.01

eval_fun = rosenbrock

# ------------------------------------------- RUN IT -------------------------------------

# Create the Fitness and Individual classes
creator.create("FitnessMin", base.Fitness, weights=(-1.0,))
creator.create("Individual", list, fitness=creator.FitnessMin)

# Register toolbox functions
toolbox = base.Toolbox()
toolbox.register("attr_float", random.uniform, pmin_, pmax_)
toolbox.register("individual", tools.initRepeat, creator.Individual, toolbox.attr_float, n=n_dim)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)

toolbox.register("mate", tools.cxBlend, alpha=alpha)
toolbox.register("mutate", tools.mutGaussian, mu=0, sigma=1, indpb=mut)
toolbox.register("select", tools.selTournament, tournsize=3)
toolbox.register("evaluate", eval_fun)

fill = []
fill_t = []
for i in range(10):
    if __name__ == "__main__":
        start_time = time.time() #time
        pop, stats, hof = main(popul=300,generations=400, parent=par, mutate=mut)
        end_time = time.time() #time
        elapsed_time = end_time - start_time
        # print("Best individual is: ",  hof[0])
        # print("Best fitness value is: ", hof[0].fitness.values[0])
        # print("Time to execute: ", elapsed_time)
        fill.append(hof[0].fitness.values[0])
        fill_t.append(elapsed_time)

print("Best fitness value is: ", min(fill))
print("Best AVG fitness value is: ", np.mean(fill))
print('-------------------------------------')
print("Best AVG time is: ", np.mean(fill_t))
# Out:
# Best fitness value is:  7.058250989270057e-05
# Best AVG fitness value is:  0.6863065624088395
# -------------------------------------
# Best AVG time is:  1.8277217864990234

# %%
random.seed(12345)
# define parameters
n_dim = 10
pmin_ = -5
pmax_ = 10
alpha = 0.8
par = 0.7
mut = 0.01

eval_fun = rosenbrock

# ------------------------------------------- RUN IT -------------------------------------

# Create the Fitness and Individual classes
creator.create("FitnessMin", base.Fitness, weights=(-1.0,))
creator.create("Individual", list, fitness=creator.FitnessMin)

# Register toolbox functions
toolbox = base.Toolbox()
toolbox.register("attr_float", random.uniform, pmin_, pmax_)
toolbox.register("individual", tools.initRepeat, creator.Individual, toolbox.attr_float, n=n_dim)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)

toolbox.register("mate", tools.cxBlend, alpha=alpha)
toolbox.register("mutate", tools.mutGaussian, mu=0, sigma=1, indpb=mut)
toolbox.register("select", tools.selTournament, tournsize=3)
toolbox.register("evaluate", eval_fun)

fill = []
fill_t = []
for i in range(10):
    if __name__ == "__main__":
        start_time = time.time() #time
        pop, stats, hof = main(popul=300,generations=400, parent=par, mutate=mut)
        end_time = time.time() #time
        elapsed_time = end_time - start_time
        # print("Best individual is: ",  hof[0])
        # print("Best fitness value is: ", hof[0].fitness.values[0])
        # print("Time to execute: ", elapsed_time)
        fill.append(hof[0].fitness.values[0])
        fill_t.append(elapsed_time)

print("Best fitness value is: ", min(fill))
print("Best AVG fitness value is: ", np.mean(fill))
print('-------------------------------------')
print("Best AVG time is: ", np.mean(fill_t))
# Out:
# Best fitness value is:  0.01733047153888498
# Best AVG fitness value is:  4.283135564565223
# -------------------------------------
# Best AVG time is:  2.4522732734680175

# %%
random.seed(12345)
# define parameters
n_dim = 20
pmin_ = -5
pmax_ = 10
alpha = 0.8
par = 0.7
mut = 0.01

eval_fun = rosenbrock

# ------------------------------------------- RUN IT -------------------------------------

# Create the Fitness and Individual classes
creator.create("FitnessMin", base.Fitness, weights=(-1.0,))
creator.create("Individual", list, fitness=creator.FitnessMin)

# Register toolbox functions
toolbox = base.Toolbox()
toolbox.register("attr_float", random.uniform, pmin_, pmax_)
toolbox.register("individual", tools.initRepeat, creator.Individual, toolbox.attr_float, n=n_dim)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)

toolbox.register("mate", tools.cxBlend, alpha=alpha)
toolbox.register("mutate", tools.mutGaussian, mu=0, sigma=1, indpb=mut)
toolbox.register("select", tools.selTournament, tournsize=3)
toolbox.register("evaluate", eval_fun)

fill = []
fill_t = []
for i in range(10):
    if __name__ == "__main__":
        start_time = time.time() #time
        pop, stats, hof = main(popul=300,generations=400, parent=par, mutate=mut)
        end_time = time.time() #time
        elapsed_time = end_time - start_time
        # print("Best individual is: ",  hof[0])
        # print("Best fitness value is: ", hof[0].fitness.values[0])
        # print("Time to execute: ", elapsed_time)
        fill.append(hof[0].fitness.values[0])
        fill_t.append(elapsed_time)

print("Best fitness value is: ", min(fill))
print("Best AVG fitness value is: ", np.mean(fill))
print('-------------------------------------')
print("Best AVG time is: ", np.mean(fill_t))
# Out:
# Best fitness value is:  2.26997078055191
# Best AVG fitness value is:  50.92301440027761
# -------------------------------------
# Best AVG time is:  3.4934385776519776
